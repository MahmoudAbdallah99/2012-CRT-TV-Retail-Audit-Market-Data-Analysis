# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing & Inspecting data

# %%
df = pd.read_excel('Assignment 2.xlsx', sheet_name='CRT TV 2012')

# %%
df
# Out:
#           Brand name                                  MODEL     REALFLAT  \
# 0              TOTAL                                  TOTAL          NaN
# 1            TORNADO                                21F7XEL     REALFLAT
# 2            TOSHIBA                               21W12XEL     REALFLAT
# 3                ECO                               NGT-21T8  NO REALFLAT
# 4    SILVER SCREEN C                                   2118  NO REALFLAT
# 5              ARION  ELEGANCE PURE 21/TV 21207-0110-139755     REALFLAT
# 6            TORNADO                                14V7XEL  NO REALFLAT
# 7            TORNADO                               21SF7XEL     REALFLAT
# 8    SILVER SCREEN C                                   1406     REALFLAT
# 9            TOSHIBA                               14W10XEL  NO REALFLAT
# 10   SILVER SCREEN C                                 14 B-3  NO REALFLAT
# 11   TIBA INTERNATIO                               CT 15WXS  NO REALFLAT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 13 columns):
# Brand name               562 non-null object
# MODEL                    562 non-null object
# REALFLAT                 560 non-null object
# SIZE/INCH                560 non-null object
# SOUND SYSTEM             560 non-null object
# DVD PLAYER/REC.          560 non-null object
# SALES UNITS %            562 non-null float64
# SALES UNITS              562 non-null int64
# SALES VALUE %            562 non-null float64
# TH. SALES VALUE EGP      562 non-null int64
# PRICE EGP                562 non-null int64
# Weighted Distribution    562 non-null float64
# Numeric Distribution     562 non-null float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 57.2+ KB

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000205B645A048>,
# ...
#       dtype=object)

# %% [markdown]
# ## Preprocessing data

# %%
df.isnull().sum()
# Out:
# Brand name               0
# MODEL                    0
# REALFLAT                 2
# SIZE/INCH                2
# SOUND SYSTEM             2
# DVD PLAYER/REC.          2
# SALES UNITS %            0
# SALES UNITS              0
# SALES VALUE %            0
# TH. SALES VALUE EGP      0
# PRICE EGP                0
# Weighted Distribution    0
# Numeric Distribution     0
# dtype: int64

# %%
#delete the first and last row
df = df.iloc[1: , :]
df = df.iloc[:-1 , :]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().round(2)
# Out:
#        SALES UNITS %  SALES UNITS  SALES VALUE %  TH. SALES VALUE EGP  \
# count         560.00       560.00         560.00               560.00
# mean            0.17      1681.99           0.17               902.12
# std             0.56      5235.43           0.66              3326.41
# min             0.00         1.00           0.00                 0.00
# 25%             0.00        48.00           0.00                25.75
# 50%             0.00       244.50           0.00               136.50
# 75%             0.10      1091.25           0.10               621.25
# max             9.40     88465.00          11.20             56630.00
#
#        PRICE EGP  Weighted Distribution  Numeric Distribution
# count     560.00                 560.00                560.00
# mean      642.80                   1.51                  0.59
# std       457.80                   4.01                  1.83
# min        67.00                   0.00                  0.00
# ...

# %%
df['SIZE/INCH'].unique()
# Out:
# array([21, 14, 15, 17, 20, 29, 16, 'UNKNOWN', 28, 25, 34], dtype=object)

# %%
df['SIZE/INCH'].value_counts()
# Out:
# 21         275
# 14         120
# 29          88
# 20          21
# 25          17
# 15          14
# 17          13
# 16           8
# 34           2
# UNKNOWN      1
# 28           1
# Name: SIZE/INCH, dtype: int64

# %%
df.loc[df["SIZE/INCH"] == "UNKNOWN", "SIZE/INCH"] = 21

# %%
df['DVD PLAYER/REC.'].unique()
# Out:
# array(['NO DVD', 'DVD PLAYER', 'N.A.'], dtype=object)

# %%
df['DVD PLAYER/REC.'].value_counts()
# Out:
# NO DVD        546
# N.A.           13
# DVD PLAYER      1
# Name: DVD PLAYER/REC., dtype: int64

# %%
df.loc[df["DVD PLAYER/REC."] == "N.A.", "DVD PLAYER/REC."] = 'NO DVD'

# %% [markdown]
# ## Exploring & Analising data

# %%
df.groupby('Brand name')["SALES VALUE %", "SALES UNITS %"].apply(lambda x : x.astype(float).sum())
# Out:
#                  SALES VALUE %  SALES UNITS %
# Brand name
# A-ONE                      0.0            0.0
# AISTAR                     0.0            0.0
# AIWA                       0.0            0.0
# AIWA TRONIC                0.0            0.0
# AKAI                       0.0            0.0
# AMH                        0.4            0.5
# ARION                      3.3            3.2
# ATA INTERNATION            0.0            0.0
# BERTY NATIONAL             1.0            1.5
# BN                         0.1            0.2
# CAIRA                      0.4            0.5
# CLASS                      0.3            0.3
# CT NETIONEL                0.0            0.0
# DAEWOO                     0.2            0.0
# DALY STAR                  0.0            0.0
# DALY STARS                 0.1            0.1
# ECO                        4.4            4.9
# EGA INTERNATION            0.6            0.8
# EGY NATIONAL               0.0            0.0
# ...

# %%
df.groupby('REALFLAT')["SALES VALUE %"].apply(lambda x : x.astype(float).sum())
# Out:
# REALFLAT
# NO REALFLAT    41.8
# REALFLAT       56.0
# Name: SALES VALUE %, dtype: float64

# %%
df.groupby('SIZE/INCH')["SALES VALUE %"].apply(lambda x : x.astype(float).sum())
# Out:
# SIZE/INCH
# 14    14.9
# 15     2.1
# 16     0.2
# 17     1.0
# 20     1.7
# 21    70.8
# 25     0.0
# 28     0.1
# 29     7.0
# 34     0.0
# Name: SALES VALUE %, dtype: float64

# %%
df.groupby('DVD PLAYER/REC.')["SALES VALUE %"].apply(lambda x : x.astype(float).sum())
# Out:
# DVD PLAYER/REC.
# DVD PLAYER     0.6
# NO DVD        97.2
# Name: SALES VALUE %, dtype: float64

# %%
df.groupby('SOUND SYSTEM')["SALES VALUE %"].apply(lambda x : x.astype(float).sum())
# Out:
# SOUND SYSTEM
# MONO       2.7
# STEREO    95.1
# Name: SALES VALUE %, dtype: float64

# %%
import scipy.stats

x = df["Weighted Distribution"]
y = df["TH. SALES VALUE EGP"]


slope, intercept, r, p, stderr = scipy.stats.linregress(x, y)

line = f'Regression line: y={intercept:.2f}+{slope:.2f}x, r={r:.2f}'
line

fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x, label=line)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()

result.pvalue
# Out:
# 4.778832457610578e-288

# %%
x = df["Numeric Distribution"]
y = df["TH. SALES VALUE EGP"]

result= scipy.stats.linregress(x, y)

slope, intercept, r, p, stderr = scipy.stats.linregress(x, y)

line = f'Regression line: y={intercept:.2f}+{slope:.2f}x, r={r:.2f}'
line

fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x, label=line)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()



result.pvalue
# Out:
# 4.778832457610578e-288

# %%
df.groupby('MODEL')["SALES VALUE %", "Numeric Distribution","Weighted Distribution" ].apply(lambda x : x.astype(float).sum())
# Out:
#                        SALES VALUE %  Numeric Distribution  \
# MODEL
# (DAHAN) GOLDEN EYE 17            0.1                   0.1
# 14                               1.2                   5.5
# 14 B-3                           0.9                   5.8
# 14 FU7RB                         0.0                   0.2
# 14 FU7RB- T2                     0.0                   0.0
# 14 G SUPER FLAT                  0.0                   0.1
# 14 GP                            0.5                   3.2
# 14 NO REALFLAT                   0.0                   0.0
# 14 TV                            0.0                   0.0
# 1406                             1.1                   5.3
# 1406 "14"                        0.0                   0.0
# 1408                             0.3                   1.7
# 1410                             0.1                   0.4
# 1430                             0.3                   1.7
# 1432                             0.6                   3.2
# ...

# %%
df
# Out:
#           Brand name                                  MODEL     REALFLAT  \
# 1            TORNADO                                21F7XEL     REALFLAT
# 2            TOSHIBA                               21W12XEL     REALFLAT
# 3                ECO                               NGT-21T8  NO REALFLAT
# 4    SILVER SCREEN C                                   2118  NO REALFLAT
# 5              ARION  ELEGANCE PURE 21/TV 21207-0110-139755     REALFLAT
# 6            TORNADO                                14V7XEL  NO REALFLAT
# 7            TORNADO                               21SF7XEL     REALFLAT
# 8    SILVER SCREEN C                                   1406     REALFLAT
# 9            TOSHIBA                               14W10XEL  NO REALFLAT
# 10   SILVER SCREEN C                                 14 B-3  NO REALFLAT
# 11   TIBA INTERNATIO                               CT 15WXS  NO REALFLAT
# 12           GOLDSKY                             GST-2156PF     REALFLAT
# ...

# %%
df.to_csv('Assignment 2 modified.csv')
